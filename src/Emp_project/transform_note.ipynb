# %%
data = [
    (101,"John","IT",50000),
    (102,"Alice","IT",60000),
    (103,"Bob","HR",45000)
]
col=["emp_id","emp_name","dept","salary"]
df=spark.createDataFrame(data,col)
df.show()

# %%
from src.transforms import *
dr=inc_sal(df)
dr.show()

# %%
from src.transforms import *
dr=inc_sal(df)
dr.show()

# %%
import importlib
import src.transforms

importlib.reload(src.transforms)

from src.transforms import *

# %%
dr = inc_sal(df)
dr.show()
